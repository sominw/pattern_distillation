# %%
import os

import pandas as pd
import numpy as np

# %%
data_path = "/work/frink/shaib.c/pattern_distillation/original_data"

# %%
cochrane = pd.read_csv(os.path.join(data_path, 'cochrane_train_inputs.csv'), index_col=0)

rotten_tomatoes_movies = pd.read_csv(os.path.join(data_path, 'rotten_tomatoes_movies.csv'))
rotten_tomatoes_critics = pd.read_csv(os.path.join(data_path, 'rotten_tomatoes_critic_reviews.csv'))

# %%
cochrane.head()
# Out:
#    ReviewID      PMID                                              Title  \
# 0  CD007697  16394043  Aggressive surgical effort and improved surviv...
# 1  CD000174   8627434  Prophylactic indomethacin therapy in the first...
# 2  CD000174   2677294  Indomethacin reduces the risks of severe intra...
# 3  CD000174   3373404  Administration of indomethacin for the prevent...
# 4  CD000174   3321891  Early intravenous indomethacin prolongs respir...
#
#                                             Abstract
# 0  Residual disease after initial surgery for ova...
# 1  To determine whether a course of low-dose indo...
# 2  A prospective, random selection, double-blind ...
# 3  One hundred twenty-two preterm infants were en...
# 4  Infants weighing 1500 g at birth requiring eit...

# %%
rotten_tomatoes_critics.head()
# Out:
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255    Louise Keller       False           Urban Cinefile
# 2            m/0814255              NaN       False      FILMINK (Australia)
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# 3  Whether audiences will get behind The Lightnin...
# 4  What's really lacking in The Lightning Thief i...

# %%
rotten_tomatoes_movies.columns
# Out:
# Index(['rotten_tomatoes_link', 'movie_title', 'movie_info',
#        'critics_consensus', 'content_rating', 'genres', 'directors', 'authors',
#        'actors', 'original_release_date', 'streaming_release_date', 'runtime',
#        'production_company', 'tomatometer_status', 'tomatometer_rating',
#        'tomatometer_count', 'audience_status', 'audience_rating',
#        'audience_count', 'tomatometer_top_critics_count',
#        'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count'],
#       dtype='object')
